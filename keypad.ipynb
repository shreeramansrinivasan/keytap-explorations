# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from IPython.display import Audio

# %%
sample_rate =  24000;
sample_bit_width = 32;
filepath = "C:\Users\Janani\Downloads\chal.raw"
# Out:
#   Cell In[5], line 3
#     filepath = "C:\Users\Janani\Downloads\chal.raw"
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
sample_rate =  24000;
sample_bit_width = 32;
filepath = 'C:\Users\Janani\Downloads\chal.raw'
# Out:
#   Cell In[7], line 3
#     filepath = 'C:\Users\Janani\Downloads\chal.raw'
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
audio_data = np.fromfile(filepath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 audio_data = np.fromfile(filepath)
#
# NameError: name 'filepath' is not defined

# %%
filepath
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 filepath
#
# NameError: name 'filepath' is not defined

# %%
sample_rate =  24000;
sample_bit_width = 32;
filepath = r'C:\Users\Janani\Downloads\chal.raw'

# %%
filepath
# Out:
# 'C:\\Users\\Janani\\Downloads\\chal.raw'

# %%
audio_data = np.fromfile(filepath)

# %%
audio_data
# Out:
# array([-1.06099790e-314, -1.06099790e-314, -1.06099790e-314, ...,
#         1.17488828e-026,  1.79953537e-027,  6.50119518e-027])

# %%
size(audio_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 size(audio_data)
#
# NameError: name 'size' is not defined

# %%
length(audio_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 length(audio_data)
#
# NameError: name 'length' is not defined

# %%
len(audio_data)
# Out:
# 1163264

# %%
len(audio_data[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 len(audio_data[0])
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
plt.plot(audio_data)

# %%
plt.plot(audio_data(1:100000))
# Out:
#   Cell In[33], line 1
#     plt.plot(audio_data(1:100000))
#                          ^
# SyntaxError: invalid syntax

# %%
plt.plot(audio_data[:100000])

# %%
2^64
# Out:
# 66

# %%
import math

# %%
math.pow(2,64)
# Out:
# 1.8446744073709552e+19

# %%
audio_data[0]
# Out:
# -1.0609978955e-314

# %%
plt.plot(audio_data[1:10000])

# %%
math.max(audio_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 math.max(audio_data)
#
# AttributeError: module 'math' has no attribute 'max'

# %%
max(audio_data)
# Out:
# 0.9967123255688105

# %%
len(audio_data)*2
# Out:
# 2326528

# %%
1163264*(1/24e3)
# Out:
# 48.46933333333333

# %%
audio_data = np.fromfile(filepath,dtype=float32
                        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 audio_data = np.fromfile(filepath,dtype=float32
#       2                         )
#
# NameError: name 'float32' is not defined

# %%
audio_data
# Out:
# array([-1.06099790e-314, -1.06099790e-314, -1.06099790e-314, ...,
#         1.17488828e-026,  1.79953537e-027,  6.50119518e-027])

# %%
len(audio_data)
# Out:
# 1163264

# %%
man(np.fromfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 man(np.fromfile)
#
# NameError: name 'man' is not defined

# %%
help(np.fromfile)
# Out:
# Help on built-in function fromfile in module numpy:
#
# fromfile(...)
#     fromfile(file, dtype=float, count=-1, sep='', offset=0, *, like=None)
#
#     Construct an array from data in a text or binary file.
#
#     A highly efficient way of reading binary data with a known data-type,
#     as well as parsing simply formatted text files.  Data written using the
#     `tofile` method can be read using this function.
#
#     Parameters
#     ----------
#     file : file or str or Path
#         Open file object or filename.
#
#         .. versionchanged:: 1.17.0
#             `pathlib.Path` objects are now accepted.
#
#     dtype : data-type
#         Data type of the returned array.
#         For binary files, it is used to determine the size and byte-order
#         of the items in the file.
#         Most builtin numeric types are supported and extension types may be supported.
#
#         .. versionadded:: 1.18.0
#             Complex dtypes.
#
#     count : int
# ...

# %%
audio_data = np.fromfile(filepath, dtype=float32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 audio_data = np.fromfile(filepath, dtype=float32)
#
# NameError: name 'float32' is not defined

# %%
audio_data=np.fromfile(filepath,dtype='float32')

# %%
len(audio_data)
# Out:
# 2326528

# %%
audio_data
# Out:
# array([-0.        , -0.        , -0.        , ...,  0.00086144,
#         0.00086152,  0.0009773 ], dtype=float32)

# %%
plt.plot(audio_data)

# %%
plt.plot(audio_data[:10000])

# %%
plt.plot(audio_data[:200000])

# %%
fft_out = np.fft.fft(audio_data);

# %%
plt.plot(np.abs(fft_out))

# %%
len(fft_out)
# Out:
# 2326528

# %% [markdown]
# ## plt.plot(audio_data[:10000
#          ])

# %%
plt.plot(audio_data[:100000])

# %%
plt.plot(audio_data[15000:25000])

# %%
plt.plot(audio_data[20000:25000])

# %%
fft_chunk = np.fft.fft(audio_data[18000:25000])

# %%
plt.plot(np.abs(fft_chunk))
